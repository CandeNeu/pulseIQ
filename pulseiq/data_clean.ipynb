# %%
import pandas as pd

# %%
# !pip install openpyxl
# Out:
# ...
#
# [notice] A new release of pip is available: 24.3.1 -> 26.2.1
# [notice] To update, run: pip install --upgrade pip

# %%
#!wget -O raw_data/data.zip 'https://ndownloader.figshare.com/files/944109'
# Out:
# raw_data/data.zip: No such file or directory

# %%
#!unzip raw_data/example.zip
# Out:
# unzip:  cannot find or open raw_data/example.zip, raw_data/example.zip.zip or raw_data/example.zip.ZIP.

# %%
path = '/home/davig/code/pulseIQ/raw_data/Data File/PPG-BP dataset.xlsx'

df = pd.read_excel(path, header=1)
df.head()
# Out:
#    Num.  subject_ID Sex(M/F)  Age(year)  Height(cm)  Weight(kg)  \
# 0     1           2   Female         45         152          63
# 1     2           3   Female         50         157          50
# 2     3           6   Female         47         150          47
# 3     4           8     Male         45         172          65
# 4     5           9   Female         46         155          65
#
#    Systolic Blood Pressure(mmHg)  Diastolic Blood Pressure(mmHg)  \
# 0                            161                              89
# 1                            160                              93
# 2                            101                              71
# 3                            136                              93
# 4                            123                              73
#
#    Heart Rate(b/m)  BMI(kg/m^2)          Hypertension Diabetes  \
# 0               97    27.268006  Stage 2 hypertension      NaN
# ...

# %%
df.to_parquet('exam.parquet')
